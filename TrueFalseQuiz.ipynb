# %%
import random 
from tkinter import *
from tkinter import ttk
import tkinter.messagebox

# %%
quizwindow=Tk()
quizwindow.title("QUIZ!")
quizwindow.geometry("1000x600")
quizwindow.configure(bg="Sky Blue")

# %%
head=Frame(quizwindow,bg="Blue",bd=20,pady=5,relief=RIDGE)
head.pack(side=TOP)
app_title=Label(head,text="True-False Quiz",
                font=('arial',60,'bold'),bd=21,
                bg="Black",fg="White",justify=CENTER)
app_title.grid(row=0,column=0)

# %%
def Reset():
    name.set("")
    QUIZTEXT.delete("1.0",END)
    a1.set("")
    a2.set("")
    a3.set("")
    a4.set("")
    a5.set("")
    a6.set("")
    a7.set("")
    a8.set("")
    a9.set("")
    a10.set("")
def Exit():
    exitmsg=tkinter.messagebox.askyesno("Exit Quiz?",
                                        "Please Confirm!")
    if exitmsg>0:
        quizwindow.destroy()
        return
 
def GenerateQuiz():
    QUIZTEXT.insert(END,"HELLO "+name.get()+" HERE IS THE QUIZ!\n\t ALL THE BEST!")
    QUIZTEXT.insert(END,"\n1.Adults have a total of 34 teeth.")
    QUIZTEXT.insert(END,"\n2.An ostrich’s eye is bigger than its brain.")
    QUIZTEXT.insert(END,"\n3.A jellyfish is 95% water.")
    QUIZTEXT.insert(END,"\n4.Bacon was part of the first meal eaten on the Moon.")
    QUIZTEXT.insert(END,"\n5.Watermelons are originally from Australia.")
    QUIZTEXT.insert(END,"\n6.There are over 330 different dog breeds in the world.")
    QUIZTEXT.insert(END,"\n7.Electrons are larger than molecules.")
    QUIZTEXT.insert(END,"\n8.Adult dogs and adult humans have the same number of teeth.")
    QUIZTEXT.insert(END,"\n9.The deadliest earthquake of 2017 took place in Iran and Iraq.")
    QUIZTEXT.insert(END,"\n10.Spinach originally comes from Iran.")

# %%
lab1=Label(quizwindow,text="ENTER YOUR NAME: ",font=(60))
lab1.place(x=10,y=200)
name=StringVar()
name.set("")
e1=Entry(quizwindow,width=20,bd=5,textvariable=name)
e1.place(x=200,y=200)

B1=Button(quizwindow,text="GENERATE QUIZ",font=(40),command=GenerateQuiz)
B2=Button(quizwindow,text="RESET",command=Reset,font=(40))
B3=Button(quizwindow,text="EXIT",command=Exit,font=(40))
B1.place(x=10,y=230)
B2.place(x=180,y=230)
B3.place(x=280,y=230)

Instruct=Text(quizwindow,height=15,width=55,bg="Light Gray",font=(10),bd=4)
Instruct.place(x=10,y=270)
Instruct.insert(END,"\tWELCOME TO THE QUIZ APPLICATION!")
Instruct.insert(END,"\n\t\tHere are the Instructions: ")
Instruct.insert(END,"\n1. When you click on the GENERATE QUIZ button \n\tthe quiz is visible on the screen")
Instruct.insert(END,"\n2. Read the questions and give your answers as either\n\t T for True and F for False in the entry boxes on the screen")
Instruct.insert(END,"\n3. After entering the answers click on check Answer Button\n\t to check the answers.")
Instruct.insert(END,"\n4. The results are visible on the same screen.")
Instruct.insert(END,"\n\n\tHOPE YOU ENJOY THE QUIZ!\n\t\tALL THE BEST!!!")

QUIZTEXT=Text(quizwindow,width=45,height=10,bg="White",font=(10),bd=4)
QUIZTEXT.place(x=550,y=200)

lab2=Label(quizwindow,text="ENTER ANSWERS",font=(20))
lab2.place(x=670,y=390)
lab3=Label(quizwindow,text="ANSWER 1: ",font=(20))
lab3.place(x=550,y=420)
lab3=Label(quizwindow,text="ANSWER 2: ",font=(20))
lab3.place(x=550,y=440)
lab3=Label(quizwindow,text="ANSWER 3: ",font=(20))
lab3.place(x=550,y=460)
lab3=Label(quizwindow,text="ANSWER 4: ",font=(20))
lab3.place(x=550,y=480)
lab3=Label(quizwindow,text="ANSWER 5: ",font=(20))
lab3.place(x=550,y=500)
a1=StringVar()
a2=StringVar()
a3=StringVar()
a4=StringVar()
a5=StringVar()
e2=Entry(quizwindow,textvariable=a1,width=5)
e2.place(x=660,y=420)
e3=Entry(quizwindow,textvariable=a2,width=5)
e3.place(x=660,y=440)
e4=Entry(quizwindow,textvariable=a3,width=5)
e4.place(x=660,y=460)
e5=Entry(quizwindow,textvariable=a4,width=5)
e5.place(x=660,y=480)
e6=Entry(quizwindow,textvariable=a5,width=5)
e6.place(x=660,y=500)
lab3=Label(quizwindow,text="ANSWER 6: ",font=(20))
lab3.place(x=750,y=420)
lab3=Label(quizwindow,text="ANSWER 7: ",font=(20))
lab3.place(x=750,y=440)
lab3=Label(quizwindow,text="ANSWER 8: ",font=(20))
lab3.place(x=750,y=460)
lab3=Label(quizwindow,text="ANSWER 9: ",font=(20))
lab3.place(x=750,y=480)
lab3=Label(quizwindow,text="ANSWER 10: ",font=(20))
lab3.place(x=750,y=500)
a6=StringVar()
a7=StringVar()
a8=StringVar()
a9=StringVar()
a10=StringVar()
e7=Entry(quizwindow,textvariable=a6,width=5)
e7.place(x=860,y=420)
e8=Entry(quizwindow,textvariable=a7,width=5)
e8.place(x=860,y=440)
e9=Entry(quizwindow,textvariable=a8,width=5)
e9.place(x=860,y=460)
e10=Entry(quizwindow,textvariable=a9,width=5)
e10.place(x=860,y=480)
e11=Entry(quizwindow,textvariable=a10,width=5)
e11.place(x=860,y=500)

# %%
answers=['F','T','T','T','F','T','F','F','T','T']   
total_score=0
def CheckAns():
    QUIZTEXT.delete("1.0",END)
    global total_score
    global answers
    if(a1.get().upper()=="F"):
        total_score+=1
    if(a2.get().upper()=="T"):
        total_score+=1
    if(a3.get().upper()=="T"):
        total_score+=1
    if(a4.get().upper()=="T"):
        total_score+=1
    if(a5.get().upper()=="F"):
        total_score+=1
    if(a6.get().upper()=="T"):
        total_score+=1
    if(a7.get().upper()=="F"):
        total_score+=1
    if(a8.get().upper()=="F"):
        total_score+=1
    if(a9.get().upper()=="T"):
        total_score+=1
    if(a10.get().upper()=="T"):
        total_score+=1
    a1.set("")
    a2.set("")
    a3.set("")
    a4.set("")
    a5.set("")
    a6.set("")
    a7.set("")
    a8.set("")
    a9.set("")
    a10.set("")
    QUIZTEXT.insert(END,"\n\tCongratulations "+name.get()+" !")
    QUIZTEXT.insert(END,"\n\n\tYour total score is: "+str(total_score))
    QUIZTEXT.insert(END,"\n\n\tACCURACY LEVEL: "+str((total_score/10)*100))
    QUIZTEXT.insert(END,"\n\n\t THANK YOU! HOPE YOU LIKE IT!")

# %%
subbtn=Button(quizwindow,text="SUBMIT ANSWERS",command=CheckAns,font=(30))
subbtn.place(x=670,y=530)

# %%
quizwindow.mainloop()
